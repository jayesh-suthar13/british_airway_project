# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
cwd=os.getcwd()
df=pd.read_csv(cwd+'/BA_reviews.csv',index_col=0)

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0  ✅ Trip Verified |   The seats were excellent, ...      5
# 1  ✅ Trip Verified |   After the nightmare of get...      9
# 2  ✅ Trip Verified |   Prior to boarding a gate a...      5
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...      3
# 4  ✅ Trip Verified | First the good news, the clu...      1
#
#                 dates          countrys
# 0  28th February 2025  (United Kingdom)
# 1  27th February 2025  (United Kingdom)
# 2  21st February 2025  (United Kingdom)
# 3  18th February 2025     (Netherlands)
# 4  14th February 2025  (United Kingdom)

# %%
df['verified']=df.reviews.str.contains("Trip Verified")

# %%
df['verified']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3495    False
# 3496    False
# 3497    False
# 3498    False
# 3499    False
# Name: verified, Length: 3500, dtype: bool

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemma= WordNetLemmatizer()

review_data=df.reviews.str.strip("✅ trip verified |")
corpus=[]
for rev in review_data:
  rev=re.sub('[^a-zA-Z]',' ',rev)
  rev=rev.lower()
  rev=rev.split()
  rev=[lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
  rev=''.join(rev)
  corpus.append(rev)

# %%
df['corpus']=corpus

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0  ✅ Trip Verified |   The seats were excellent, ...      5
# 1  ✅ Trip Verified |   After the nightmare of get...      9
# 2  ✅ Trip Verified |   Prior to boarding a gate a...      5
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...      3
# 4  ✅ Trip Verified | First the good news, the clu...      1
#
#                 dates          countrys  verified  \
# 0  28th February 2025  (United Kingdom)      True
# 1  27th February 2025  (United Kingdom)      True
# 2  21st February 2025  (United Kingdom)      True
# 3  18th February 2025     (Netherlands)      True
# 4  14th February 2025  (United Kingdom)      True
#
#                                               corpus
# 0  tripverifiedseatexcellentfeelmuchroomofficials...
# 1  tripverifiednightmaregettingtriplesecuritynair...
# 2  tripverifiedpriorboardinggateagentseemedpickel...
# 3  tripverifiedflewamsterdamlavegalayoverheathrow...
# ...

# %%
df.dtypes
# Out:
# reviews     object
# stars        int64
# dates       object
# countrys    object
# verified      bool
# corpus      object
# dtype: object

# %%
df['dates']=df['dates'].str.replace(r'(st|nd|rd|th)',"",regex=True)
df['dates']=pd.to_datetime(df['dates'],format="%d %B %Y",errors='coerce')
df['dates'].head()
# Out:
# 0   2025-02-28
# 1   2025-02-27
# 2   2025-02-21
# 3   2025-02-18
# 4   2025-02-14
# Name: dates, dtype: datetime64[ns]

# %%
df.head()
# Out:
#                                              reviews  stars      dates  \
# 0  ✅ Trip Verified |   The seats were excellent, ...      5 2025-02-28
# 1  ✅ Trip Verified |   After the nightmare of get...      9 2025-02-27
# 2  ✅ Trip Verified |   Prior to boarding a gate a...      5 2025-02-21
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...      3 2025-02-18
# 4  ✅ Trip Verified | First the good news, the clu...      1 2025-02-14
#
#            countrys  verified  \
# 0  (United Kingdom)      True
# 1  (United Kingdom)      True
# 2  (United Kingdom)      True
# 3     (Netherlands)      True
# 4  (United Kingdom)      True
#
#                                               corpus
# 0  tripverifiedseatexcellentfeelmuchroomofficials...
# 1  tripverifiednightmaregettingtriplesecuritynair...
# 2  tripverifiedpriorboardinggateagentseemedpickel...
# 3  tripverifiedflewamsterdamlavegalayoverheathrow...
# 4  tripverifiedfirstgoodnewsclubsuitehugeimprovem...

# %%
df.stars.unique()
# Out:
# array([ 5,  9,  3,  1,  4,  7,  2,  8, 10,  6])

# %%
df.stars.value_counts()
# Out:
# stars
# 1     1750
# 2      280
# 8      280
# 5      210
# 9      210
# 3      210
# 4      210
# 10     175
# 7      105
# 6       70
# Name: count, dtype: int64

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  dates  countrys  verified  corpus
# False    False  False  False     False     False     2625
#                 True   False     False     False      875
# Name: count, dtype: int64

# %%
df.dates.isnull().value_counts()
# Out:
# dates
# False    2625
# True      875
# Name: count, dtype: int64

# %%
df.drop(df[df.dates.isnull()==True].index,axis=0 ,inplace=True)

# %%
df.shape
# Out:
# (2625, 6)

# %%
df.reset_index(drop=True)
# Out:
#                                                 reviews  stars      dates  \
# 0     ✅ Trip Verified |   The seats were excellent, ...      5 2025-02-28
# 1     ✅ Trip Verified |   After the nightmare of get...      9 2025-02-27
# 2     ✅ Trip Verified |   Prior to boarding a gate a...      5 2025-02-21
# 3     ✅ Trip Verified |   I flew from Amsterdam to L...      3 2025-02-18
# 4     ✅ Trip Verified | First the good news, the clu...      1 2025-02-14
# ...                                                 ...    ...        ...
# 2620  Not Verified |   Singapore to Heathrow. Busine...      1 2024-07-16
# 2621  Not Verified |   I reported my damaged/ruined ...      1 2024-07-15
# 2622  Not Verified |   On March 1st, I flew from Ber...      1 2024-07-09
# 2623  Not Verified | The WORST customer experience! ...      1 2024-07-05
# 2624  Not Verified |   Had to cancel my flight month...      1 2024-07-01
#
#               countrys  verified  \
# 0     (United Kingdom)      True
# ...

# %%
df.to_csv(cwd+"/cleaned-BA-reviews.csv")
